# %% [markdown]
# <a href="https://colab.research.google.com/github/Aban6/Teaching_OOP-for-Business-Applications/blob/main/Class1_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part One
# **Class 1**

# %% [markdown]
# **Let's get started!**
#
# *insert a link*
#
# [link text](https://colab.research.google.com/)
#
# *insert an image*
#
# ![python-programming-language.png](data:image/png;base64,...)

# %% [markdown]
# # Part Two

# %% [markdown]
# **Class 2**

# %%
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %% [markdown]
# **Python fundamentals**

# %% [markdown]
# **Numbers**

# %% [markdown]
# Clearly sometimes you will want to manipuate your data. You can do simple things like add, subtract, multipy, divide, or even find the remainder.

# %%
2+2
# Out:
# 4

# %%
3*2
# Out:
# 6

# %%
10/5
# Out:
# 2.0

# %%
11%2
# Out:
# 1

# %% [markdown]
# **integers vs. float numbers**

# %%
int = 1
float = 3.145678952222

float
# Out:
# 3.145678952222

# %%
round(float,3)
# Out:
# 3.146

# %% [markdown]
# **Strings**
#
# **Hello World!**

# %% [markdown]
# Strings
# Strings are used ALL THE TIME in Python. Strings are enclosed in quotes. Python treats single quotes the same as double quotes (but be consistent).
#
# Double quotes allow you to enclose single quotes.
#
# There are also triple double quotes """...""" They allow you to write strings that span multiple lines.
#
# There are many, many built-in functionalities that you will eventually learn. It is impossible to cover (and remember) them all in one sitting.

# %%
print ("Hello World!")
# Out:
# Hello World!

# %%
my_txt = "classroom"
my_txt
# Out:
# 'classroom'

# %% [markdown]
# **Accessing parts of a String**

# %% [markdown]
# You can access an entire string variable, or just parts of it. Square brackets are used to specify the index of the data you want. (Indices always start at 0.)

# %%
#accessing each character by index
my_txt[0]
# Out:
# 'c'

# %%
my_txt[5:9]
# Out:
# 'room'

# %%
my_txt[5:]
# Out:
# 'room'

# %%
my_txt[:5]
# Out:
# 'class'

# %%
address = '''San Diego
CA
USA'''
print(address)
# Out:
# San Diego
# CA
# USA

# %%
#create a list from a string
new_list = 'x y z d f g'.split()
new_list
# Out:
# ['x', 'y', 'z', 'd', 'f', 'g']

# %% [markdown]
# **String Operators**

# %% [markdown]
# String operators are special bits of code that ONLY WORK ON STRINGS. So while a "+" will add two numbers, it will concatenate Strings instead of adding them.

# %%
b = "Fall"+"2023"

# %%
b
# Out:
# 'Fall2023'

# %% [markdown]
# **Variables**

# %% [markdown]
# In order to save data for later use you create a variable. Luckily in Python "creating" a variables is as simple as coming up with a name and assigning a value.

# %%
a = 3**2

# %%
a
# Out:
# 9

# %% [markdown]
# *practice*

# %%
housing = 1500
groceries = 250
restaurants = 300
coffee = 45
print (housing)
# Out:
# 1500

# %%
monthly_expenses = housing+groceries+restaurants+coffee
print(monthly_expenses)
# Out:
# 2095

# %%
item1 = "housing"
item2 = "groceries"
item3 = "restaurants"
item4 = "coffee"
print("Monthly expense items include:",item1,item2,item3,item4)
# Out:
# Monthly expense items include: housing groceries restaurants coffee

# %% [markdown]
# **Lists**

# %%
monthly_expenses = ["housing","groceries","restaurants","coffee"]
monthly_expenses
# Out:
# ['housing', 'groceries', 'restaurants', 'coffee']

# %%
monthly_expenses[0]
# Out:
# 'housing'

# %%
monthly_expenses[0:2]
# Out:
# ['housing', 'groceries']

# %%
monthly_expenses[0] = "rent"

# %%
monthly_expenses
# Out:
# ['rent', 'groceries', 'restaurants', 'coffee']

# %%
monthly_expenses[-1]
# Out:
# 'coffee'

# %%
school = ["Book", "laptop",9,'pens']
school
# Out:
# ['Book', 'laptop', 9, 'pens']

# %%
school.append("shoes")
school
# Out:
# ['Book', 'laptop', 9, 'pens', 'shoes']

# %%
school.insert(2,"shoes")
school
# Out:
# ['Book', 'laptop', 'shoes', 9, 'pens', 'shoes']

# %%
#adding lists
school+monthly_expenses
# Out:
# ['Book',
#  'laptop',
#  'shoes',
#  9,
#  'pens',
#  'shoes',
#  'rent',
#  'groceries',
#  'restaurants',
#  'coffee']

# %%
"coffee" in school
# Out:
# False

# %%
len(school)
# Out:
# 6

# %% [markdown]
# **Conditions**

# %% [markdown]
# Write a program that asks user to input a number. Then, if the number is above 100, the program tells if the number is odd or even.

# %%
num = input ("Give me a number: ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-62d94bc45e37> in <cell line: 1>()
# ----> 1 num = input ("Give me a number: ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
# ...

# %%
num = int(num)
if num>100:
  print("Your number is above 100.")
  if num%2==0:
    print("Your number is even.")
  else:
    print("Your number is odd.")
else:
  print("Your number is below 100. Try again...")
  num = input ("Give me a number: ")
  num = int(num)
  if num%2!=0 or num<100:
    print("Program failed.")
  else:
    print("Success!")

# %%
#Exercise 1: Check if a number is positive, negative, or zero.

#Exercise 2: Determine if a year is a leap year or not.

#Exercise 3: Check if a number is even or odd.

#Exercise 4: Determine the grade based on a student's score.

#Exercise 5: Check if a given string is a palindrome.

# %%
#Exercise 1
num = float(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %%
#Exercise 2
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print(year, "is a leap year")
else:
    print(year, "is not a leap year")

# %%
#Exercise 3
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
#Exercise 4
score = int(input("Enter the student's score: "))
if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >= 60:
    print("Grade: D")
else:
    print("Grade: F")

# %%
#Exercise 5
string = input("Enter a string: ")
if string == string[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")

# %% [markdown]
# **Iterations**

# %%
#Practice
#print 40 to 50

for i in range(40,51):
  print(i)

# %%
#Manual operation
numbers = [1500, 25, 86, 3314]
total = numbers[0] + numbers[1] + numbers[2] +numbers[3]
total

# %%
#Automatic operation
total = 0
for num in numbers:
  total += num

total

# %%
#Exercise 1:
#In the toal number example, print the index of each number and then print the annual total
total = 0
for i in range(len(numbers)):
  print("Index: ",i+1,"Number: ", numbers[i])
  total = total+numbers[i]

print("Total is: ", total)

# %%
fruits = ["apples", "oranges", 'strawberries', 3]
drinks = ["tea", "coffee", 2, 'water']

shopping = [fruits, drinks]

for  i in range(len(shopping)):
    print(i, shopping[i])

# %%
#stop the for loop when the wanted item is found using "break"
main_room = "classroom"
all_rooms = ["offices", "hallways", "staircases", "classroom", "library"]
for room in all_rooms:
  if room == main_room:
    print ("I found the main room: ",room)
    break
  else:
    print("The main room is not ", room)

# %%
#skip a step in the loop using "continue"
#print square of numbers between 1 to 5 EXCEPT even numbers

for i in range(1,6):
  if i%2 == 0:
    continue
  else:
    print(i*i)

# %%
#Exercise 2: Print even numbers from 1 to 20 using a while loop.
num = 1
while num <= 20:
    if num % 2 == 0:
        print(num)
    num += 1

# %%
#Exercise 3: Print a multiplication table for a given number using a for loop.
num = int(input("Enter a number:"))
for i in range (1,11):
  print(num,"x",i, "=",num*i)

# %%
#Exercise 4: Reverse a given string using a while loop.
string = (input("Enter a word:"))
reversed_string = ""
index = len(string)-1

while index>=0:
  reversed_string += string[index]
  index -= 1
print(reversed_string)

# %%
#Exercise 5: Print the Fibonacci series up to a given number using a while loop.
limit = int(input("Enter a number: "))
a, b = 0,1
c=a
while b < limit:
  c=a
  a=b
  b=a+c

  print(a)

# %%
#print without a newline
limit = int(input("Enter a number: "))
a, b = 0, 1
print("Fibonacci series:")
while a <= limit:
    print(a, end=" ")
    a, b = b, a + b

# %% [markdown]
# # Part Three

# %% [markdown]
# **Class 3**

# %% [markdown]
# **Collections**

# %% [markdown]
# Dictionaries

# %%
#Dictionaries
# Exampe 1: Create a dictionary of person details
person = {
    'name': 'Alice',
    'age': 25,
    'city': 'New York'
}

# %% [markdown]
# In this example, we have created a dictionary called person. It contains three key-value pairs:
#
# The key 'name' has the value 'Alice'.
# The key 'age' has the value 25.
# The key 'city' has the value 'New York'.

# %%
# Exampe 2: Accessing Dictionary Values
# Access values by key
print(person['name'])  # Output: Alice
print(person['age'])   # Output: 25
print(person['city'])  # Output: New York

# %% [markdown]
# You can access dictionary values by providing the corresponding key in square brackets. For example, person['name'] returns the value 'Alice'.

# %%
# Exampe 3: Modifying Dictionary Values

# Update the age
person['age'] = 26

# Add a new key-value pair
person['occupation'] = 'Engineer'

# Print the modified dictionary
print(person)

# %% [markdown]
# In this example, we have modified the value associated with the key 'age' by assigning it a new value 26. We have also added a new key-value pair 'occupation': 'Engineer' to the dictionary. The resulting dictionary will now include these changes.

# %%
#Example 4: Iterating Over a Dictionary
# Iterate over keys
for key in person:
    print("key: ", key, ", value: ", person[key])

for k,v in person.items():
  print("key: ", k, "value: ", v)
# Iterate over values
for value in person.values():
    print(value)

# Iterate over key-value pairs
for key, value in person.items():
    print(key, '=', value)

# %%
"height" in person

# %%
"age" in person

# %% [markdown]
# You can iterate over a dictionary using a for loop. By default, iterating over a dictionary will give you the keys. To iterate over the values, you can use the values() method. If you want to access both the keys and values together, you can use the items() method, which returns key-value pairs.
#
# Dictionaries are versatile and widely used in Python for various purposes. They allow you to store and retrieve data efficiently based on meaningful keys, making them a powerful tool for managing collections of related information.

# %% [markdown]
# Tuples

# %%
# Create a tuple of fruits
fruits = ("apple", "banana", "orange")

# %%
# Access the first element
print(fruits[0])  # Output: apple

# Access the last element
print(fruits[-1])  # Output: orange

# %%
# Concatenate two tuples
numbers = (1, 2, 3)
combined = fruits + numbers
print(combined)  # Output: ("apple", "banana", "orange", 1, 2, 3)

# %%
# Get the length of a tuple
print(len(fruits))  # Output: 3

# %%
# Slice a tuple to get a subset of elements
subset = fruits[1:3]
print(subset)  # Output: ("banana", "orange")

# %%
# Count the number of occurrences of an element in a tuple
count = fruits.count("banana")
print(count)  # Output: 1

# %%
# Find the index of the first occurrence of an element in a tuple
index = fruits.index("orange")
print(index)  # Output: 2

# %%
# Unpack a tuple into separate variables
name, age, city = ("Alice", 25, "New York")
print(name, age, city)  # Output: Alice 25 New York

# %%
# Iterate over a tuple
for fruit in fruits:
    print(fruit)

# %%
# Attempt to modify a tuple (will result in an error)
fruits[0] = "pear"

# %% [markdown]
# **Functions**

# %%
#Exercise 1: Calculate the sum of two numbers
def calculate_sum(a,b):
  return a+b

calculate_sum(3,8)

# %%
#Exercise 2: Find the maximum of three numbers
def max_finder (a,b,c):
  return max(a,b,c)

max_finder(3,4,8)

# %%
#Exercise 3: Count the number of uppercase letters in a string
def upper_letters (word):
  counter=0
  for char in word:
    if char.isupper():
      counter+=1
  return counter

upper_letters ("GoodBye!")

# %%
#Exercise 4: Check if a number is prime
def is_prime(num):
  if num<2:
    return False
  for i in range(2,num):
    if num%i==0:
      return False
      break
    else:
      return True
      break

is_prime(12)

# %%
#Exercise 5: write a function to calculate total expenses for multiple poeple
def total_num(lists):
  total = 0
  for item in lists:
    total +=item
  return total

Jims_expenses = [2000,3500,6800]
Jacks_expenses = [1200,652,394]
Jims_total = total_num(Jims_expenses)
Jacks_total = total_num(Jacks_expenses)

print("Jim's total expenses: ", Jims_total)
print("Jack's total expenses: ", Jacks_total)

# %%
y = 20  # Global variable

def my_function():
    global y
    print(y)
    y = 30

my_function()  # Output: 20
print(y)  # Output: 30

# %% [markdown]
# # Part Four

# %% [markdown]
# **Class 4**

# %% [markdown]
# **Object Oriented Programming**

# %% [markdown]
# **Classes**

# %%
#class

# Define a class representing a Car
class Car:

#properties
  def __init__(self, color, brand):
    self.color = color
    self.brand = brand

#methods
  def accelerate(self):
    print(f"{self.color} {self.brand} is accelerating")

  def drives(self):
    if self.brand == "Ferrari":
      print (self.name, "drives fast")
    elif self.brand == "BMW":
      print (self.brand, "drives faster")

# Create objects of the Car class
car1 = Car("red", "Ferrari")
car2 = Car("blue", "BMW")

# Accessing object attributes and methods
print(car1.color)         # Output: red
print(car2.brand)         # Output: BMW
car1.accelerate()         # Output: The red Ferrari is accelerating.
car2.drives()

# %%
# Define a class representing a BankAccount
class BankAccount:
    def __init__(self, account_number):
        self.__account_number = account_number  # Encapsulated private attribute

    def deposit(self, amount):
        # Perform necessary operations for depositing
        print(f"Depositing ${amount} to Account Number: {self.__account_number}")

    def withdraw(self, amount):
        # Perform necessary operations for withdrawal
        print(f"Withdrawing ${amount} from Account Number: {self.__account_number}")

# Create an object of the BankAccount class
account = BankAccount("1234567890")

# Accessing private attribute (not recommended)
print(account._BankAccount__account_number)  # Output: 1234567890

# Using public methods to interact with the object
account.deposit(1000)           # Output: Depositing $1000 to Account Number: 1234567890
account.withdraw(500)           # Output: Withdrawing $500 from Account Number: 1234567890

# %% [markdown]
# **File I/O**

# %%
# Opening a file in read mode
file = open("sample.txt", "r")
data = file.read()  # Reading the entire file content
print(data)
file.close()  # Closing the file

# Opening a file in write mode and writing data to it
file = open("output.txt", "w")
file.write("Hello, world!\n")
file.write("This is a test file.\n")
file.close()  # Closing the file

# %% [markdown]
# # **Part Five**

# %% [markdown]
# **pandas**

# %%
import pandas as pd
#upload a csv file on Google Colab directly from your computer
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-453d0df4-0f67-4f56-9521-4035f16e1908" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-453d0df4-0f67-4f56-9521-4035f16e1908">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Creating a datafrmae, using:**
# Google pandas io
# 1.   csv files
# 2.   Excel files
# 3.   from Python Dictionaries
# 4.   from list of tuples
# 5.   from list of Dictionaries
# 6.   sql(later)
# 7.   json(later)
# 8.   HTML(later)

# %%
import pandas as pd
#first you need to mount your google drive manually or using this code:
from google.colab import drive
drive.mount("/content/drive")
##upload a csv file on Google Colab from your GoogleDrive
#get the file path by right-clicking on it in the left side window
file_path = '/content/Excel_Sample.xlsx'
df = pd.read_excel(file_path,"Sheet1")
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-da3904676b8b> in <cell line: 8>()
#       6 #get the file path by right-clicking on it in the left side window
#       7 file_path = '/content/Excel_Sample.xlsx'
# ----> 8 df = pd.read_excel(file_path,"Sheet1")
#       9 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
# ...

# %%
file_path = '/content/Salaries.csv'
df = pd.read_csv(file_path)
df

# %%
df["BasePay"].max()

# %%
df['EmployeeName'][df['JobTitle']=='CAPTAIN III (POLICE DEPARTMENT)']

# %%
df['Benefits'].mean()

# %% [markdown]
# **creating a dataframe starting from a Dictionary**

# %%
my_data = {
    'day' : [1,2,3,4,5,6],
    'temp' : [21,23,25,28,25,23],
    'wind speed' : [5,3,4,6,7,5],
    'event' : ['sunny','sunny','cloudy', 'rain','sunny','sunny']
}
df = pd.DataFrame(my_data)
df
# Out:
#    day  temp  wind speed   event
# 0    1    21           5   sunny
# 1    2    23           3   sunny
# 2    3    25           4  cloudy
# 3    4    28           6    rain
# 4    5    25           7   sunny
# 5    6    23           5   sunny

# %% [markdown]
# **creating a dataframe from a list of tuples**

# %%
data= [
    (1,21,5,'sunny'),
    (2,23,3,'sunny'),
    (3,25,4,'cloudy'),
    (4,28,6,'rain'),
    (5,25,7,'sunny'),
    (6,23,5,'sunny')
]
df = pd.DataFrame(data, columns = ["day","temp","wind speed","event"])
df
# Out:
#    day  temp  wind speed   event
# 0    1    21           5   sunny
# 1    2    23           3   sunny
# 2    3    25           4  cloudy
# 3    4    28           6    rain
# 4    5    25           7   sunny
# 5    6    23           5   sunny

# %% [markdown]
# **creating a dataframe from a list of Dictionaries**

# %%
data = [
    {'day':1,'temp':21,'wind speed' :5,'event':'sunny'},
    {'day':2,'temp':23,'wind speed' :3,'event':'sunny'},
    {'day':3,'temp':25,'wind speed' :4,'event':'cloudy'},
    {'day':4,'temp':28,'wind speed' :6,'event':'rain'},
    {'day':5,'temp':25,'wind speed' :7,'event':'sunny'},
    {'day':6,'temp':23,'wind speed' :5,'event':'sunny'}
]
df_weather = pd.DataFrame(data)
df_weather
# Out:
#    day  temp  wind speed   event
# 0    1    21           5   sunny
# 1    2    23           3   sunny
# 2    3    25           4  cloudy
# 3    4    28           6    rain
# 4    5    25           7   sunny
# 5    6    23           5   sunny

# %%
#creating a multi-index df
list1
list2
list3 = list(zip(list1,list2))
list3 = pd.MultiIndex.from_tuples(list3)

df = pd.DataFrame(randn(6,2),list3,['column name 1','column name 2'])

df.index.names = ['name 1','name 2']
#select from outside to the inside in a multi-index df
df.loc['outer index'].loc['inner index']['column name']

#cross section
df.xs('outer index')
#for accessign the inner index
df.xs('inner index',level='name 2')

# %%
rows, columns = df_weather.shape
rows

# %%
df_weather.head()

# %%
df_weather.head(2)

# %%
df_weather.tail(2)

# %%
#slicing and indexing
df_weather[2:5]

# %%
df_weather.columns

# %%
df_weather.event

# %%
type(df_weather['event'])

# %%
df_weather[['day','temp']]

# %%
df_weather.describe()

# %%
df_weather[df_weather.temp>=25]

# %%
df_weather[df_weather.temp==df_weather.temp.max()]

# %%
#use this syntax if there is a space in a column's name
df_weather[df_weather['wind speed']==df_weather['wind speed'].max()]

# %%
df_weather[['event','temp']][df_weather['wind speed']==df_weather['wind speed'].max()]

# %%
df_weather.index

# %%
#changing the index of the dataframe and modify the original dataframe
df_weather.set_index('day', inplace=True)
df_weather
# Out:
#      temp  wind speed   event
# day
# 1      21           5   sunny
# 2      23           3   sunny
# 3      25           4  cloudy
# 4      28           6    rain
# 5      25           7   sunny
# 6      23           5   sunny

# %%
df_weather.loc[1]
# Out:
# temp             21
# wind speed        5
# event         sunny
# Name: 1, dtype: object

# %%
#reset index
df_weather.reset_index(inplace=True)
df_weather
# Out:
#    day  temp  wind speed   event
# 0    1    21           5   sunny
# 1    2    23           3   sunny
# 2    3    25           4  cloudy
# 3    4    28           6    rain
# 4    5    25           7   sunny
# 5    6    23           5   sunny

# %% [markdown]
# **Reading and Writing csv, excel files**

# %%
#read csv and change header names
df_Salaries = pd.read_csv("Salaries.csv")
df_Salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df1 = df[["EmployeeName","JobTitle"]]
df1.head()
# Out:
#         EmployeeName                                        JobTitle
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)

# %% [markdown]
# **Writing back to csv**

# %%
df.to_csv('new_data2.csv',columns=["EmployeeName","JobTitle"])

# %% [markdown]
# **Writing back to excel**

# %%
df.to_excel("new_excel.xlsx",sheet_name="summary",startrow=1,startcol=2)

# %%
import pandas as pd
#write two different dataframes into one excel file as two different sheets
with pd.ExcelWriter('weather_salary.xlsx') as writer:
  df_weather.to_excel(writer,sheet_name="weather")
  df_Salaries.to_excel(writer,sheet_name="salaries")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ecf7c68791cf> in <cell line: 3>()
#       3 with pd.ExcelWriter('weather_salary.xlsx') as writer:
# ----> 4   df_weather.to_excel(writer,sheet_name="weather")
#       5   df_Salaries.to_excel(writer,sheet_name="salaries")
#
# NameError: name 'df_weather' is not defined
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-ecf7c68791cf> in <cell line: 3>()
#       1 import pandas as pd
#       2 #write two different dataframes into one excel file as two different sheets
# ----> 3 with pd.ExcelWriter('weather_salary.xlsx') as writer:
#       4   df_weather.to_excel(writer,sheet_name="weather")
#       5   df_Salaries.to_excel(writer,sheet_name="salaries")
#
# ...

# %% [markdown]
# **Data cleaning/munging/wrangling**

# %% [markdown]
# NA or empty cells, adding or editing header names, skip first few lines if needed,modifying indices. or negative numbers when only positive is expected

# %% [markdown]
# **Selection**

# %%
#locate columns
df['column name']

#locate rows
df.loc['row name']
#or
df.iloc['numerical row index, for example 1 or 2, ...']

#locate a cell based on row and column location
df.loc['row name','column name']
#or a list of rows and a list of columns
df.loc[['row name1','row name2'],['column name1','column name2']]

#boolean value based on a condition
df_bool = df>0
df[df>0 ]

result_df = df[df['column name']>0 ]
result_df['a specific column name in that dataframe ']

#use & instead of and, | instead of or
df[(df['W']>0)&(df['y']>1)]

# %%
#drop columns
df.drop("column name to drop",axis=1,inplace = True)

#drop rows
df.drop("row name to drop",axis=0,inplace = True)

# %%
df.fillna(0, inplace=True)
df['Benefits'].mean()
# Out:
# 18924.23283887417

# %%
#specify different replacements for na cells under different columns
df.fillna({
    'Id': 'No Id',
    'Benefits': 0
})

# %%
df = pd.read_csv("Salaries.csv", na_values={
    "EmployeeName":["N.A","not available"],
    "TotalPay":["N.A","not available",-1]
})

# %%
def convert_zero(cell):
  if cell==0:
    return None
  return cell

df_excel = pd.read_excel("Excel_Sample.xlsx",converters={
    'a':convert_zero
})
df_excel
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-ab98b7351b11> in <cell line: 6>()
#       4   return cell
#       5
# ----> 6 df_excel = pd.read_excel("Excel_Sample.xlsx",converters={
#       7     'a':convert_zero
#       8 })
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# **Handling missing data: fillna, dropna, interpolate**

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Salaries.csv'
df = pd.read_csv(file_path)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#carry forward the previous value above the empty cell and put a limit of 2 means it only copies that value two times and leaves the rest as NaN
new_df = df.fillna(method="ffill", limit=2)
new_df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#copy next value (horizontally or vertically)
new_df = df.fillna(method="bfill", axis="rows")
new_df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#interpolate, default method is linear interpolation
df_new = df.interpolate()
df_new
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#fillna with the mean of a certain column
df.fillna(value=df['A'].mean())

# %%
#drop NA
new_df = df.dropna()
new_df
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
#drop NA if only all the cells ina row are empty
new_df = df.dropna(how = "all")
#or
new_df = df.dropna(thresh=1)
new_df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#replace method
import numpy as np

new_df = df.replace([0.00,1.00],np.NaN)
new_df
#or for multiple columns
new_df = df.replace({
    'BasePay':[0.00,1.00],
    'Benefits':0.00
},np.NaN)
new_df

#or
new_df= df.replace({
    -99999: np.NaN,
    'no name': 'John'
})
new_df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#replace some spme part of a cell with blank
new_df = df.replace('[A-Za-z]','',regex=True)
new_df
# Out:
#             Id EmployeeName JobTitle    BasePay  OvertimePay   OtherPay  \
# 0            1                   -    167411.18         0.00  400184.25
# 1            2                   ( )  155966.02    245131.88  137811.38
# 2            3                   ( )  212739.13    106088.18   16452.60
# 3            4                         77916.00     56120.71  198306.90
# 4            5                  ,( )  134401.60      9737.00  182234.59
# ...        ...          ...      ...        ...          ...        ...
# 148649  148650                             0.00         0.00       0.00
# 148650  148651                              NaN          NaN        NaN
# 148651  148652                              NaN          NaN        NaN
# 148652  148653                              NaN          NaN        NaN
# 148653  148654                  ,          0.00         0.00    -618.13
#
#         Benefits   TotalPay  TotalPayBenefits  Year  Notes Agency  Status
# ...

# %%
#replace some spme part of a cell with blank
new_df = df.replace({
    'BasePay': ['A-Za-z']
    },'',regex=True)
new_df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#replace a list of values with another list of values
df.replace(['worst','bad','good','great'],[1,2,3,4])

# %% [markdown]
# **Groupby**

# %%
#split, apply, combine
#Groupby
g = df.groupby('JobTitle')
#aggreagte functions
g.mean()
g.sum().loc['Custodian']
g.describe()['Custodian']

# %%
for JobTitle,JobTitle_df in g:
  print(JobTitle)
  print(JobTitle_df)
# Out:
# Streaming output truncated to the last 5000 lines.
# 67391  San Francisco     NaN
# 68183  San Francisco     NaN
# Speci
#             Id   EmployeeName              JobTitle   BasePay  OvertimePay  \
# 130361  130362    Edward Wong  Special Assistant 11  68454.02          0.0
# 147887  147888  George M Rush  Special Assistant 11   1022.82          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 130361       0.0  29556.56  68454.02          98010.58  2014    NaN
# 147887       0.0     10.22   1022.82           1033.04  2014    NaN
#
#                Agency  Status
# 130361  San Francisco     NaN
# 147887  San Francisco     NaN
# Speci
#           Id       EmployeeName              JobTitle   BasePay  OvertimePay  \
# 67002  67003  Gia Casteel-Brown  Special Assistant 13  13968.25          0.0
#
#        OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 67002       0.0   5574.06  13968.25          19542.31  2012    NaN
#
# ...

# %%
g.get_group('CAPTAIN III (POLICE DEPARTMENT)')
# Out:
#           Id       EmployeeName                         JobTitle    BasePay  \
# 1          2       GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2          3     ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 11        12   PATRICIA JACKSON  CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 61        62         ANNA BROWN  CAPTAIN III (POLICE DEPARTMENT)  102571.24
# 65        66      RICHARD PARRY  CAPTAIN III (POLICE DEPARTMENT)  185369.69
# 91        92      DONNA MEIXNER  CAPTAIN III (POLICE DEPARTMENT)  102722.40
# 93        94        JOHN MURPHY  CAPTAIN III (POLICE DEPARTMENT)  215914.03
# 125      126    SHARON FERRIGNO  CAPTAIN III (POLICE DEPARTMENT)  185369.68
# 211      212     CROCE CASCIATO  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# 214      215        JOHN FEENEY  CAPTAIN III (POLICE DEPARTMENT)  188348.55
# 225      226   STEPHEN TACCHINI  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# ...

# %%
g.max()
# Out:
#                                                     Id           EmployeeName  \
# JobTitle
# ACCOUNT CLERK                                    35638            ZAIRE EARBY
# ACCOUNTANT                                       35286          ROSALINDA TAN
# ACCOUNTANT INTERN                                34267            YUMING CHEN
# ACPO,JuvP, Juv Prob (SFERS)                     135284  Palminder K Hernandez
# ACUPUNCTURIST                                    18379                 WEN XU
# ...                                                ...                    ...
# X-RAY LABORATORY AIDE                            33182            STANLEY LEE
# X-Ray Laboratory Aide                            99852             Zhe J Chen
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS   23392          MARIO YEDIDIA
# Youth Comm Advisor                               98075           Phimy Truong
# ZOO CURATOR                                      18779            MYRON SULAK
#
# ...

# %% [markdown]
# **Concat/merge/join Dataframes**

# %%
#join dataframes
df = pd.concat([df1,df2])
#index comes from the first dataframe, unless you ignore index
pd.concat([df1,df2],ignore_index=True)
#pass keys
pd.concat([df1,df2],keys=["a keyword in df1","a keyword in df2"])
#get a subset of the merded dataframe
df.loc["a keyword in df1"]
#appending two dataframes side by side
pd.concat([df1,df2],axis=1)
#append a series to a dataframe
s = pd.Series(["Rain","Dry","Snow"], name="event")
pd.concat([df,s],axis=1)

# %%
#merge, a more efficient way than concat
df = pd.merge(df1,df2,on="a key column shared in both dataframes")
#inner join/intersection: if there are descrepancies betweem the two dataframes' specific keywords, only the common values are printed in the merged df
#unless you use union/outer join method
df = pd.merge(df1,df2,on="a keyword in both dataframes",how="outer",indicator=True)

# %%
#join
df1.join(df2)

# %% [markdown]
# **Pivot tables**

# %%
#pivot
df.pivot(index="what you want to write on the row index",columns="hat you want to write as the column headers",values="what values to include in the pivot table")

#pivot table: to summarize and aggregate data inside dataframe
df.read_csv("your csv file")
df.pivot_table(index="",columns="",aggfunc="mean, is default")#aggfunc defines the aggregation function

#if margin==True, it adds an ALL column and row and put the average value of all, there
df.pivot_table(index="",columns="",aggfunc="mean, is default",margins=True)

#grouper
df.pivot_table(index=pd.Grouper(freq='M',key='date'))#frequency is month here

# %% [markdown]
# **Handling large datasets/Memory optimization**

# %%
#keep only columns that you need
#https://pythonspeed.com/articles/pandas-load-less-data/
df=df[["column1","column2"]]
#or
pd.read_csv("csv file",usecols=["column1","column2"])
#change data type to a lower-memory usage if possible
df = pd.read_csv("voters.csv")
>>> df["Ward Number "].memory_usage(index=False, deep=True)
550688
>>> df["Ward Number "].max()
11
>>> df["Ward Number "].min()
1
>>> df = pd.read_csv("voters.csv", dtype={"Ward Number ": "int8"})
>>> df["Ward Number "].memory_usage(index=False, deep=True)
68836

#changing data type from string to category if possible
df = pd.read_csv("voters.csv", dtype={"Party Affiliation ": "category"})

#sparse series
df = pd.read_csv("voters.csv")
>>> series = df["Mailing Address - Apartment Number "]
>>> series.memory_usage(index=False, deep=True)
2623975
>>> len(series)
68836
>>> len(series.dropna())
13721
#If you have a column with lots of empty values, usually represented as NaNs, you can save memory by using a sparse column representation. It won’t waste memory storing all those empty values.
sparse_series = series.astype("Sparse[str]")
>>> len(sparse_series)
68836
>>> sparse_series.memory_usage(index=False, deep=True)
2237939

# %% [markdown]
# **Data Visualization**

# %% [markdown]
# **matplotlib**

# %% [markdown]
# We'll use functional and object-oriented method

# %% [markdown]
# See matplotlib.org/gallery.html for more examples
#
# Also matplotlib.org/api/pyplot_summary.html for the API

# %%
import matplotlib.pyplot as plt #pyplot is the main matplotlib object
#if you use Jupyter notebook, use the following line of code to show the graphs
# %matplotlib inline
#if not using Jupyter notebook, use the following code to show the graphs:
#plt.show()

# %%
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

# %%
#functional method
plt.plot(x,y, 'rD',linewidth=2, linestyle='') #red Diamond

# %%
plt.plot(x,y, color = 'red',linewidth=2, linestyle='dashed', alpha=0.3) #alpha defined transparency of the plot lines

# %%
plt.plot(x,y, color = '#553266', marker = 'o', markersize=10,markerfacecolor='green', markeredgewidth=3,markeredgecolor='red', linewidth=2, linestyle='')

# %%
days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]

# %%
#axis labels
plt.xlabel("Days")
plt.ylabel("Temperature $[^o C]$")
plt.title("Weather")

plt.plot(days,max_t, label = "Max")
plt.plot(days,min_t, label = "Min")
plt.plot(days,avg_t, label = "Average")

plt.legend(loc="lower left", fontsize = "large") #or loc = "best"
plt.grid()

# %% [markdown]
# **Subplot**

# %%
#multiple plots
import matplotlib.pyplot as plt

days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]

plt.subplot(1,2,1) #one row and two columns
plt.plot(days,max_t,'g')

plt.subplot(1,2,2)
plt.plot(days,min_t,'r')

# %%
#object oriented method
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(days,max_t,'g')
axes.set_xlabel('X label')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
#object oriented method
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.15,0.25,0.3])
axes1.plot(days,max_t,'g')
axes1.set_title('title1')
axes2.plot(days,min_t,'r')
axes2.set_title('title2')
# Out:
# Text(0.5, 1.0, 'title2')

# %%
#object oriented subplot method
fig,axes = plt.subplots(nrows=1,ncols=2)


#you can iterate through the axis
#for current_ax in axes:
  #current_ax.plot(days,max_t)

#you can index the axes
axes[0].plot(days,max_t)
axes[0].set_title('title1')
axes[1].plot(days,min_t)
axes[1].set_title('title2')

plt.tight_layout() #fixes any overlappings of different plots

# %%
#Figure size and DPI
fig=plt.figure(figsize=(3,2),dpi=100)
ax=fig.add_axes([0,0,1,1])
ax.plot(days,max_t)

# %%
#Figure size and DPI
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(3,2),dpi=100)
axes[0].plot(days,max_t)
axes[1].plot(days,min_t)
plt.tight_layout() #fixes any overlappings of different plots

# %%
#plot only a part of data
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(days,max_t, color = '#553266', lw=2, ls='--')
ax.set_xlim([0,5])
ax.set_ylim([45,53])
# Out:
# (45.0, 53.0)

# %%
company = ['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,46]
profit = [40,21,32,56]

# %%
plt.bar(company,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
import numpy as np
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
#convert numerical xticks to company names
plt.xticks(xpos,company)

plt.ylabel("revenue($)")
plt.title("US Tech Stocks")
plt.bar(xpos-0.2,revenue,width = 0.4 ,label ="revenue")
plt.bar(xpos+0.2,profit, width = 0.4,label ="profit")

plt.legend()

# %%
#convert numerical xticks to company names
plt.yticks(xpos,company)

plt.xlabel("revenue/profit($)")
plt.title("US Tech Stocks")
plt.barh(xpos-0.2,revenue, height = 0.4 ,label ="revenue")
plt.barh(xpos+0.2,profit, height = 0.4 ,label ="profit")

plt.legend()

# %% [markdown]
# **Histograms**

# %%
scores = [112,51,86,165,142,95,65,75,82,103,142,121,98]

# %%
plt.hist(scores)
# Out:
# (array([1., 1., 2., 2., 2., 1., 1., 2., 0., 1.]),
#  array([ 51. ,  62.4,  73.8,  85.2,  96.6, 108. , 119.4, 130.8, 142.2,
#         153.6, 165. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(scores, bins=5)
# Out:
# (array([2., 4., 3., 3., 1.]),
#  array([ 51. ,  73.8,  96.6, 119.4, 142.2, 165. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(scores, bins=5, rwidth = 0.7)
# Out:
# (array([2., 4., 3., 3., 1.]),
#  array([ 51. ,  73.8,  96.6, 119.4, 142.2, 165. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(scores, bins=[80,100,140,200], rwidth = 0.7, color = 'g')
# Out:
# (array([4., 3., 3.]),
#  array([ 80., 100., 140., 200.]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(scores, bins=[80,100,140,200], rwidth = 0.7, color = 'g',histtype='step' )
# Out:
# (array([4., 3., 3.]),
#  array([ 80., 100., 140., 200.]),
#  [<matplotlib.patches.Polygon at 0x7c8fb6db1180>])

# %%
scores_1 = [112,51,86,165,142,95,65,75,82,103,142,121,98]
scores_2 = [120,56,65,120,35,85,132,165,45,58,124,153,68]

# %%
plt.hist([scores_1,scores_2],bins=5,color=['pink','orange'], label=['group1','group2'])
plt.xlabel('Scores')
plt.ylabel('Total number of team members')
plt.title('Team Scores')
plt.legend()

# %%
plt.hist([scores_1,scores_2],bins=5,color=['pink','orange'], label=['group1','group2'], orientation='horizontal')
plt.xlabel('Scores')
plt.ylabel('Total number of team members')
plt.title('Team Scores')
plt.legend()

# %% [markdown]
# **Pie chart**

# %%
month_exp = [210,153,456,65,85]
items = ["grocery", "restaurant","rent","coffe","books"]

# %%
plt.pie(month_exp,labels = items, radius = 1.2, autopct ='%0.2f%%', shadow = True,explode=[0,0.15,0,0,0])
plt.show()

# %%
plt.pie(month_exp,labels = items, radius = 1.2, autopct ='%0.2f%%', shadow = True,explode=[0,0.15,0,0,0],startangle=45)
plt.savefig("piechart.png",bbox_inches="tight",dpi=300) #fits the image borders to the chart size

# %%
plt.pie(month_exp,labels = items, radius = 1.2, autopct ='%0.2f%%', shadow = True,explode=[0,0.15,0,0,0],startangle=45)
plt.savefig("piechart_wide margin.png",bbox_inches="tight", pad_inches = 2) #wide margin

# %%
plt.pie(month_exp,labels = items, radius = 1.2, autopct ='%0.2f%%', shadow = True,explode=[0,0.15,0,0,0],startangle=45)
plt.savefig("piechart_transparent.png",bbox_inches="tight", transparent = True) #transparent background

# %% [markdown]
# scatterplot, boxplot

# %% [markdown]
# **Seaborn**

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips['total_bill'], kde=True, bins = 30)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg') #kind is 'scatter' as default. it can be 'kde', 'hex', etc

# %%
sns.pairplot(tips, hue='sex', palette = 'cool') #with hue, you can add categorical columns

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# **Categorical Plots**

# %%
import numpy as np

sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips, hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips, hue='smoker',split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill',data=tips, jitter=True, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips) # is not recommended for presentations, it's more for data exploratory purposes for data scientists. for presentation, use Boxplot, countplot, or barplot
sns.swarmplot(x='day',y='total_bill',data=tips, color='black') # is not recommended for large datasets
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# **Matrix Plot**

# %%
#heatmaps: data should be in a matrix form
import seaborn as sns
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#for a heatmap, data should be in a matrix form
tc = tips.corr()
tc
# Out:
# <ipython-input-60-547e469b40d4>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tc = tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
health = sns.load_dataset('healthexp')
health.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
pl = health.corr()
# Out:
# <ipython-input-123-3ed44424daea>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pl = health.corr()

# %%
sns.heatmap(pl, annot = True, linecolor='black',linewidth=0.1,cmap='magma')
# Out:
# <Axes: >

# %%
pv = health.pivot_table(index='Year',columns='Country',values='Life_Expectancy')

# %%
sns.heatmap(pv)
# Out:
# <Axes: xlabel='Country', ylabel='Year'>

# %%
import seaborn as sns
fl = sns.load_dataset('flights')

# %%
pv2=fl.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.clustermap(pv2,cmap='coolwarm')

# %%
sns.clustermap(pv2,cmap='coolwarm',standard_scale=1)

# %% [markdown]
# **Grids**

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)

# %%
#facetgrid
g = sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.histplot,'total_bill')

# %% [markdown]
# **Regression Plots**

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex',markers=['o','v'],scatter_kws={'s':100}) #scatter_kws={'s':100} changes the size of markers

# %%
sns.lmplot(x='total_bill', y='tip', data=tips,col='day',hue='sex',aspect=0.6)

# %% [markdown]
# **Style and Color**

# %%
sns.set_style('ticks') #white, darkgrid, whitegrid
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_context('poster',font_scale=1) #can be 'notebook'
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_context('notebook')
sns.lmplot(x='total_bill',y='tip',data=tips, hue='sex',palette='RdGy') #look into matplotlib colormap webpage

# %% [markdown]
# **Pandas Built-in Data Visualization**

# %% [markdown]
# For a quick analysis of data:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.DataFrame(abs(np.random.randn(1000,4)),columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0  0.521235  0.787928  1.395118  1.512043
# 1  1.261105  0.423512  1.221477  0.123604
# 2  1.549222  0.296950  1.187198  1.328607
# 3  0.756791  2.816063  0.771797  0.264180
# 4  1.062008  1.897329  0.479341  1.387431

# %%
df['a'].plot.hist()
#or
df['a'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['a'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df['a'].plot.kde()
#or
df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.bar()
df.plot.bar(stacked=True)
df.plot.line(x='Year',y='B',figsize=(12,3),lw=1)
df.plot.scatter(x='A',y='B', c='C') #c='C' gives you a black and white style plot
df.plot.scatter(x='A',y='B', c='C') # gives you a black and white style plot
df.plot.scatter(x='A',y='B', c='C',cmap = 'coolwarm') #'coolwarm' gives you a color style plot to show 3 columns A, B, and C
df.plot.scatter(x='A',y='B', s=df['C']) #gives you a scatter plot wiht different size dots showing how big 'C' is at each crossing point of A and B
df.plot.box()

# %% [markdown]
# **Plotly**
# Try this in Jupyter and it'll work great for creating interactive graphs
# Refer to Udemy course: 01-Plotly and Cufflinks

# %%
pip install chart-studio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 2.4 MB/s eta 0:00:00
# ...

# %%
pip install plotly

# %%
# !pip install cufflinks
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import chart_studio.plotly as py

# %%
from plotly import __version__

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df.head()
# Out:
#           A         B         C         D
# 0  1.175474  0.932247 -1.252925 -0.860756
# 1 -0.596472  0.124718  0.914757  0.961799
# 2 -0.078547  0.239054  0.568274  1.141109
# 3 -0.477806 -2.140014  1.735884 -0.922581
# 4  0.742651 -0.761522  1.487967 -0.236455

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers')
# Out:
# <div>                            <div id="f7d44e8c-ca3c-4f54-9a27-4a13f532910c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Geographical Maps**

# %% [markdown]
# Use Jupyter Notebook and Plotly for Geographical maps
